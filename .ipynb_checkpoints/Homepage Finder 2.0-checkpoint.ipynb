# %%
import openpyxl as xl
import pprint as pp
import urllib3
from bs4 import BeautifulSoup
import requests
import numpy as np
import time

# %%
#Load xlsx file into Python
wb = xl.load_workbook('output.xlsx') #Open Input workbook
journals = wb['journal_sheet'] #Open journals worksheet
urls = wb["url_sheet"]
num_rows = len(tuple(journals.rows))

#journal_sheet column map
#Col 0/A = journal name
#Col 1/B = Publisher
#Col 2/C = ISSN
#Col 3/D = EISSN
#Col 4/E = Country
#Col 5/F = Language
#Col 6/G = Category
#Col 7/H = Submission Guidelines URL

# %%
def get_url(row, source):
    #Alias varibles for readability
    
    journal = row[0]
    publisher = row[1]
    issn = row[2]
    eissn = row[3]
    target = row[8]
    
    #Check for each attribute in URL and replace with appropriate variable
    
    if "J_U_NAME" in source:
        #replace J_U_NAME with lowercase journal name and replace space with an underscore
        temp_name = journal.value.lower().replace(" ","_")
        target = source.replace("J_U_NAME", temp_name)
        source = target
    if "JNAME" in source:
        #Replace JNAME with lowercase journal name and replace space with hyphen
        temp_name = journal.value.lower().replace(" ", "-") 
        target = source.replace("JNAME",temp_name)
        source = target
    if "EISSN" in source:
        #Replace EISSN with actual EISSN, replacing space with hyphen
        temp_name = eissn.value.replace("-","")
        target = source.replace("EISSN", temp_name)
        source = target
    if "E_H_SSN" in source:
        #Replace EISSN with actual EISSN, keeping hyphens
        temp_name = eissn.value
        target = source.replace("E_H_SSN", temp_name)
        source = target
    if "ISSN" in source:
        #Replace ISSN with actual ISSN, replacing space with hyphen
        temp_name = issn.value.replace("-","")
        target = source.replace("ISSN", temp_name)
        source = target
    if "I_H_SSN" in source:
        #Replace ISSN with actual ISSN, keeping hyphens
        temp_name = issn.value
        target = source.replace("I_H_SSN", temp_name)
        source = target
    return target

# %%
#Iterate over all rows, find homepage
#TAKES VERY VERY LONG
home_page_url = "https://www.researchgate.net/journal/I_H_SSN_J_U_NAME"
limit = 0 #recomended for testing

#headers = requests.utils.default_headers() #Reduces change of blocking
#headers.update({
 #   'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
  #  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
   # 'accept-encoding': 'gzip, deflate, br',
    #'accept-language': 'en-US,en:q=0.9'
#})
headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
}

delays = [7, 4, 6, 2, 10, 19]


for row in journals.iter_rows(max_col=9, min_row=2, max_row=num_rows):
    if limit == 5:
        break
    #try:
    delay = np.random.choice(delays)
    time.sleep(delay)
        
    page = requests.get(get_url(row, home_page_url), headers=headers)
    soup = BeautifulSoup(page.text,'html.parser')
    for link in soup.find_all("a"):
        print(link)
        row[8].value = link.get('href')
        limit +=1
        
   # except:
    #    continue
# Out:
# <a href="http://www.enable-javascript.com/" rel="nofollow noopener" target="_blank">
#                         instructions how to enable JavaScript in your web browser</a>
# <a href="http://www.enable-javascript.com/" rel="nofollow noopener" target="_blank">
#                         instructions how to enable JavaScript in your web browser</a>
# <a href="http://www.enable-javascript.com/" rel="nofollow noopener" target="_blank">
#                         instructions how to enable JavaScript in your web browser</a>
# <a href="http://www.enable-javascript.com/" rel="nofollow noopener" target="_blank">
#                         instructions how to enable JavaScript in your web browser</a>
# <a href="http://www.enable-javascript.com/" rel="nofollow noopener" target="_blank">
#                         instructions how to enable JavaScript in your web browser</a>

# %%
wb.save('output.xlsx')

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.124 Safari/537.36',
}
page = requests.get("https://www.researchgate.net/journal/0038-0385_Sociology", headers=headers)
soup = BeautifulSoup(page.text,'html.parser')
#for link in soup.find_all("a", {"class": "nova-e-link nova-e-link--color-blue nova-e-link--theme-bare"}):
print(soup)
# Out:
# <html>
# <head>
# <script nonce="vGCJGxHKDQzLLwu2H0rFtcLRgt3KFxJz">
#         eval(function(p,a,c,k,e,d){e=function(c){return c};if(!''.replace(/^/,String)){while(c--){d[c]=k[c]||c}k=[function(e){return d[e]}];e=function(){return'\\w+'};c=1};while(c--){if(k[c]){p=p.replace(new RegExp('\\b'+e(c)+'\\b','g'),k[c])}}return p}('(12(){7 37=12(35,30){28(7 5=0;5<35.19;5++){28(7 8=0;8<30.19;8++){9(35[5+8]!==30[8]){49;}9(8===30.19-1){11 5;}}}11-1;};7 36;47{67[0]();}56(20){36=20;}9(37(36.52,\'54\')>-1){11;}9(10.55||10.57||10.58||10.59||10.60||10.61||10.62){11;}7 43=(12(){7 23="65+/=";11 12(13){7 27="";7 31,22,21,34,33,25,24;7 5=0;13=66(42(13));53(5<13.19){31=13.29(5++);22=13.29(5++);21=13.29(5++);34=31>>2;33=((31&3)<<4)|(22>>4);25=((22&15)<<2)|(21>>6);24=21&63;9(46(22)){25=24=64;}40 9(46(21)){24=64;}27=27+23.26(34)+23.26(33)+23.26(25)+23.26(24);}11 27;}})(),45=12(32){7 20="";28(7 5=0;5<32.19;5++){20=20+51.50(32.29(5)^48);}11 20;};(12(14){7 17=69 44();17.72=12(){9(17.89==44.68){9(17.91==92){10.93.94(14.41);}}};7 8=\'\';28(7 18 95 14){9(14.88(18)){9(8.19===0){8=\'?\'+18+\'=\'+14[18];}40{8+=\'&\'+18+\'=\'+14[18];}}}17.97("98","99://100.102.104/86.74.75.76"+8,70);17.77();})({79:38,80:103,81:38+103,41:"/83/84-105",87:"82",73:42(43((45("71==")))),85:39.78((1+39.101())*96).90(16)});})()',10,106,'|||||i||var|q|if|window|return|function|input|dt|||xmlhttp|key|length|e|chr3|chr2|keySpace|enc4|enc3|charAt|output|for|charCodeAt|query|chr1|s|enc2|enc1|str|err|indexOfString|521|Math|else|origPath|encodeURIComponent|b64|XMLHttpRequest|enc|isNaN|try|4115|break|fromCharCode|String|stack|while|phantomjs|_phantom|catch|__phantomas|Buffer|emit|spawn|webdriver|domAutomation|||ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789|unescape|null|DONE|new|true|ZDgyOTA2NjU4N2Q5YmI4NDUxZGRlNzgyMmExNWMyMjUyNWJhMDI0ZWZhMzE2NjIxMDlmM2E3NzFjZWQ2MTM1MQ|onreadystatechange|tk|ClientValidation|ajax|html|send|floor|a|b|res|1536337110|journal|0038|v|application|ts|hasOwnProperty|readyState|toString|status|200|location|replace|in|0x10000|open|GET|https|www|random|researchgate||net|0385_Sociology'.split('|'),0,{}))
#     </script>
# <meta content="10;URL='https://www.researchgate.net/application.ClientValidation.html?origPath=/journal/0038-0385_Sociology'" http-equiv="refresh"/>
# <style>
#         .c-box-warning {
#             border: 1px solid #FAC8AF;
#             background-color: #FADECF;
#         }
#
#         .c-box-warning {
#             margin: 10px 0;
#             padding: 10px 15px;
#         }
#
#         div {
#             display: block;
#         }
#
#         body {
#             position: relative;
#             margin: 0;
#             font-size: 0.75rem;
#             line-height: 1.5;
#             font-family: "Roboto", Arial, sans-serif;
#             color: #111111;
#             text-align: left;
#             height: 100%;
#             word-wrap: break-word;
#         }
#     </style>
# <noscript>
# <div class="c-box-warning" style="text-align: center;">
# <div style="margin: auto; padding:10px;">
# <b>For full functionality of ResearchGate it is necessary to enable JavaScript.
#                     Here are the <a href="http://www.enable-javascript.com/" rel="nofollow noopener" target="_blank">
#                         instructions how to enable JavaScript in your web browser</a>.</b>
# </div>
# </div>
# </noscript>
# </head>
# <body>
# <div style="text-align: center; margin-top: 100px;">
# <h3>Please, wait while we are validating your browser</h3>
# <img src="data:image/gif;base64,..."/>
# </div>
# </body>
# </html>
