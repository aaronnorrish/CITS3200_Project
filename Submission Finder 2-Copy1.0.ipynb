# %%
import openpyxl as xl
import pprint as pp
import requests

# %%
#Load xlsx file into Python
wb = xl.load_workbook('input2.xlsx') #Open Input workbook
journals = wb['journal_sheet'] #Open journals worksheet
urls = wb["url_sheet"]
num_rows = len(tuple(journals.rows))

#journal_sheet column map
#Col 0/A = journal name
#Col 1/B = Publisher
#Col 2/C = ISSN
#Col 3/D = EISSN
#Col 4/E = Country
#Col 5/F = Language
#Col 6/G = Category
#Col 7/H = Submission Guidelines URL

# %%
#Iterate through the url sheet to find the submission page URL outlines

access_methods = {}
publishers = []
url_methods = []

for row in urls.iter_rows(min_row=2, max_col=8, max_row=40):
    if row[0].value != 'SPRINGER':
        publishers.append(row[0].value)
        url_methods.append(row[7].value)
        print(row[0].value)
    
    
access_methods = dict(zip(publishers,url_methods))

home_access_methods = {}
publishers = []
url_methods = []

for row in urls.iter_rows(min_row=2, max_col=8, max_row=40):
    if row[0].value != 'SPRINGER':
        publishers.append(row[0].value)
        url_methods.append(row[4].value)
        print(row[0].value)
    
    
    
home_access_methods = dict(zip(publishers,url_methods))
# Out:
# TAYLOR & FRANCIS INC
# WILEY
# SAGE PUBLICATIONS INC
# ELSEVIER
# CAMBRIDGE UNIV PRESS
# OXFORD UNIV PRESS
# WALTER DE GRUYTER GMBH
# JOHNS HOPKINS UNIV PRESS
# UNIV CHICAGO PRESS
# EMERALD GROUP PUBLISHING LTD
# BRILL ACADEMIC PUBLISHERS
# JOHN BENJAMINS PUBLISHING CO
# AMER PSYCHOLOGICAL ASSOC
# DUKE UNIV PRESS
# DE GRUYTER MOUTON
# ACADEMIC PRESS INC ELSEVIER SCIENCE
# PALGRAVE MACMILLAN LTD
# MIT PRESS
# BIOMED CENTRAL LTD
# EDINBURGH UNIV PRESS
# EDUCATIONAL PUBLISHING FOUNDATION-AMERICAN PSYCHOLOGICAL ASSOC
# UNIV CALIFORNIA PRESS
# HOGREFE & HUBER PUBLISHERS
# CONSEJO SUPERIOR INVESTIGACIONES CIENTIFICAS-CSIC
# ANNUAL REVIEWS
# UNIV TORONTO PRESS INC
# PENN STATE UNIV PRESS
# UNIV ILLINOIS PRESS
# INFORMS
# PRESSES UNIV FRANCE
# KARGER
# INDIANA UNIV PRESS
# FRANZ STEINER VERLAG GMBH
# ACADEMIC PRESS LTD- ELSEVIER SCIENCE LTD
# W B SAUNDERS CO-ELSEVIER INC
# UNIV TEXAS PRESS
# PEETERS
# LIVERPOOL UNIV PRESS
# TAYLOR & FRANCIS INC
# WILEY
# SAGE PUBLICATIONS INC
# ELSEVIER
# CAMBRIDGE UNIV PRESS
# OXFORD UNIV PRESS
# WALTER DE GRUYTER GMBH
# JOHNS HOPKINS UNIV PRESS
# UNIV CHICAGO PRESS
# EMERALD GROUP PUBLISHING LTD
# BRILL ACADEMIC PUBLISHERS
# JOHN BENJAMINS PUBLISHING CO
# AMER PSYCHOLOGICAL ASSOC
# DUKE UNIV PRESS
# DE GRUYTER MOUTON
# ACADEMIC PRESS INC ELSEVIER SCIENCE
# PALGRAVE MACMILLAN LTD
# MIT PRESS
# BIOMED CENTRAL LTD
# EDINBURGH UNIV PRESS
# EDUCATIONAL PUBLISHING FOUNDATION-AMERICAN PSYCHOLOGICAL ASSOC
# UNIV CALIFORNIA PRESS
# HOGREFE & HUBER PUBLISHERS
# CONSEJO SUPERIOR INVESTIGACIONES CIENTIFICAS-CSIC
# ANNUAL REVIEWS
# UNIV TORONTO PRESS INC
# PENN STATE UNIV PRESS
# UNIV ILLINOIS PRESS
# INFORMS
# PRESSES UNIV FRANCE
# KARGER
# INDIANA UNIV PRESS
# FRANZ STEINER VERLAG GMBH
# ACADEMIC PRESS LTD- ELSEVIER SCIENCE LTD
# W B SAUNDERS CO-ELSEVIER INC
# UNIV TEXAS PRESS
# PEETERS
# LIVERPOOL UNIV PRESS

# %%
#Iterate through journals and replace None Values with empty strings
for row in journals.iter_rows(min_row=2, max_col=7, max_row=num_rows):
    for col in row:
        if col.value == None:
            col.value = ""

# %%
def get_url(row, source, home_url):
    #Alias varibles for readability
    
    journal = row[0]
    publisher = row[1]
    issn = row[2]
    eissn = row[3]
    target = row[7]
    home_page = row[8]
    #Check for each attribute in URL and replace with appropriate variable
    #print("Source =" + source)
    
    if "ABBREVIATION" in source:
        try:
            print(home_page.value)
            print(home_url)
            print(source)
            x = home_page.value.split('/')
            y = home_url.split('/')
            z = source.split('/')
            print(x[0::])
            print(y[0::])
            print(z[0::])
            pos = (y.index("ABBREVIATION"))
            #print(pos)
            abbreviation = x[pos]
            #print(abbreviation)
            temp = z.replace("ABBREVIATION", abbreviation)
            slash = '/'
            target = slash.join(temp)
            print('Success')
        except:
            print('Failure')
        
    if "J_U_NAME" in source:
        #replace J_U_NAME with lowercase journal name and replace space with an underscore
        temp_name = journal.value.lower().replace(" ","_")
        target = source.replace("J_U_NAME", temp_name)
        source = target
    if "JNAME" in source:
        #Replace JNAME with lowercase journal name and replace space with hyphen
        temp_name = journal.value.lower().replace(" ", "-") 
        target = source.replace("JNAME",temp_name)
        source = target
    if "EISSN" in source:
        #Replace EISSN with actual EISSN, replacing space with hyphen
        temp_name = eissn.value.replace("-","")
        target = source.replace("EISSN", temp_name)
        source = target
    if "E_H_SSN" in source:
        #Replace EISSN with actual EISSN, keeping hyphens
        temp_name = eissn.value
        target = source.replace("E_H_SSN", temp_name)
        source = target
    if "ISSN" in source:
        #Replace ISSN with actual ISSN, replacing space with hyphen
        temp_name = issn.value.replace("-","")
        target = source.replace("ISSN", temp_name)
        source = target
    if "I_H_SSN" in source:
        #Replace ISSN with actual ISSN, keeping hyphens
        temp_name = issn.value
        target = source.replace("I_H_SSN", temp_name)
        source = target
    return target

# %%
#Iterate over all rows, find the URL outline and return the submission outline Page

for row in journals.iter_rows(max_col=9, min_row=2, max_row=num_rows):
    #Check if submission page has already been found, and if homepage hage has been found
    #try:
    #print(row[0].value)
    if(row[1].value != 'SPRINGER' and row[1].value != 'TAYLOR & FRANCIS INC'):
    
        if(row[7].value == None and row[8].value[0:4] == 'http'):
            #print('^^^ No Submission page, found homepage')
            #if not found, and a homepage has been found
            for key, value in home_access_methods.items():
                #print(row[0].value)
                if key == row[1].value: #if publisher names match list of identified access_methods
                    for ikey,ivalue in access_methods.items():
                        if key == ikey and value != None and ivalue != None:
                            #print('1:' + access_methods[row[1].value] + '\n2' + home_access_methods[row[1].value] + '\n3' + row[8].value)
                            x = get_url(row, access_methods[row[1].value], home_access_methods[row[1].value])#Pass row and url outline
                            #print("=============================================")
                            #print(x.value)
                            
    #except:
        #continue
# Out:
# http://content.apa.org/journals/ort
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'ort']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/amp
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'amp']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/dev
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'dev']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/emo
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'emo']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/pha
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'pha']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/hea
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'hea']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://www.springerlink.com/openurl.asp?genre=journal&issn=1072-5245
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'www.springerlink.com', 'openurl.asp?genre=journal&issn=1072-5245']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/abn
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'abn']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/apl
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'apl']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/com
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'com']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/ccp
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'ccp']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/cou
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'cou']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/edu
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'edu']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/xan
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'xan']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/xap
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'xap']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/xge
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'xge']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://www.apa.org/pubs/journals/xhp/index.aspx
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'xhp', 'index.aspx']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/xlm
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'xlm']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/fam
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'fam']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/ocp
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'ocp']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/psp
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'psp']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://www.springerlink.com/openurl.asp?genre=journal&issn=0147-7307
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'www.springerlink.com', 'openurl.asp?genre=journal&issn=0147-7307']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://www.informaworld.com/openurl?genre=journal&issn=0899-5605
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'www.informaworld.com', 'openurl?genre=journal&issn=0899-5605']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/neu
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'neu']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/pro
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'pro']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/pas
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'pas']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/bul
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'bul']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/met
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'met']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/rev
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'rev']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/ser
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'ser']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/pag
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'pag']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/law
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'law']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://www.atypon-link.com/openurl?genre=journal&stitle=scpq
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'www.atypon-link.com', 'openurl?genre=journal&stitle=scpq']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://www.apa.org/pubs/journals/spy/
# http://www.apa.org/pubs/journals/ABBREVIATION/
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'spy', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://arjournals.annualreviews.org/loi/anthro
# https://www.annualreviews.org/journal/ABBREVIATION
# https://www.annualreviews.org/page/authors/general-information#ABBREVIATION
# ['http:', '', 'arjournals.annualreviews.org', 'loi', 'anthro']
# ['https:', '', 'www.annualreviews.org', 'journal', 'ABBREVIATION']
# ['https:', '', 'www.annualreviews.org', 'page', 'authors', 'general-information#ABBREVIATION']
# Failure
# http://arjournals.annualreviews.org/loi/clinpsy
# https://www.annualreviews.org/journal/ABBREVIATION
# https://www.annualreviews.org/page/authors/general-information#ABBREVIATION
# ['http:', '', 'arjournals.annualreviews.org', 'loi', 'clinpsy']
# ['https:', '', 'www.annualreviews.org', 'journal', 'ABBREVIATION']
# ['https:', '', 'www.annualreviews.org', 'page', 'authors', 'general-information#ABBREVIATION']
# Failure
# http://arjournals.annualreviews.org/loi/energy
# https://www.annualreviews.org/journal/ABBREVIATION
# https://www.annualreviews.org/page/authors/general-information#ABBREVIATION
# ['http:', '', 'arjournals.annualreviews.org', 'loi', 'energy']
# ['https:', '', 'www.annualreviews.org', 'journal', 'ABBREVIATION']
# ['https:', '', 'www.annualreviews.org', 'page', 'authors', 'general-information#ABBREVIATION']
# Failure
# http://arjournals.annualreviews.org/loi/lawsocsci
# https://www.annualreviews.org/journal/ABBREVIATION
# https://www.annualreviews.org/page/authors/general-information#ABBREVIATION
# ['http:', '', 'arjournals.annualreviews.org', 'loi', 'lawsocsci']
# ['https:', '', 'www.annualreviews.org', 'journal', 'ABBREVIATION']
# ['https:', '', 'www.annualreviews.org', 'page', 'authors', 'general-information#ABBREVIATION']
# Failure
# http://arjournals.annualreviews.org/loi/polisci
# https://www.annualreviews.org/journal/ABBREVIATION
# https://www.annualreviews.org/page/authors/general-information#ABBREVIATION
# ['http:', '', 'arjournals.annualreviews.org', 'loi', 'polisci']
# ['https:', '', 'www.annualreviews.org', 'journal', 'ABBREVIATION']
# ['https:', '', 'www.annualreviews.org', 'page', 'authors', 'general-information#ABBREVIATION']
# Failure
# http://arjournals.annualreviews.org/loi/psych
# https://www.annualreviews.org/journal/ABBREVIATION
# https://www.annualreviews.org/page/authors/general-information#ABBREVIATION
# ['http:', '', 'arjournals.annualreviews.org', 'loi', 'psych']
# ['https:', '', 'www.annualreviews.org', 'journal', 'ABBREVIATION']
# ['https:', '', 'www.annualreviews.org', 'page', 'authors', 'general-information#ABBREVIATION']
# Failure
# http://arjournals.annualreviews.org/loi/publhealth
# https://www.annualreviews.org/journal/ABBREVIATION
# https://www.annualreviews.org/page/authors/general-information#ABBREVIATION
# ['http:', '', 'arjournals.annualreviews.org', 'loi', 'publhealth']
# ['https:', '', 'www.annualreviews.org', 'journal', 'ABBREVIATION']
# ['https:', '', 'www.annualreviews.org', 'page', 'authors', 'general-information#ABBREVIATION']
# Failure
# http://arjournals.annualreviews.org/loi/soc
# https://www.annualreviews.org/journal/ABBREVIATION
# https://www.annualreviews.org/page/authors/general-information#ABBREVIATION
# ['http:', '', 'arjournals.annualreviews.org', 'loi', 'soc']
# ['https:', '', 'www.annualreviews.org', 'journal', 'ABBREVIATION']
# ['https:', '', 'www.annualreviews.org', 'page', 'authors', 'general-information#ABBREVIATION']
# Failure
# http://www.annals-general-psychiatry.com/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.annals-general-psychiatry.com', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/bmcgeriatr/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', 'bmcgeriatr', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/1472-698X/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', '1472-698X', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/bmcmededuc/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', 'bmcmededuc', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/bmcmedethics/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', 'bmcmedethics', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/bmcpalliatcare/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', 'bmcpalliatcare', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/1472-6874/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', '1472-6874', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.capmh.com/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.capmh.com', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.resource-allocation.com/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.resource-allocation.com', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.globalizationandhealth.com/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.globalizationandhealth.com', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.harmreductionjournal.com/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.harmreductionjournal.com', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/1477-7525/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', '1477-7525', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.health-policy-systems.com/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.health-policy-systems.com', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.human-resources-health.com/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.human-resources-health.com', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.implementationscience.com/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.implementationscience.com', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/1475-9276/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', '1475-9276', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/1476-072X/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', '1476-072X', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.ijmhs.com/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.ijmhs.com', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/1747-5341/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', '1747-5341', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.pophealthmetrics.com/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.pophealthmetrics.com', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/1742-4755/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', '1742-4755', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/1747-597X/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', '1747-597X', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://www.biomedcentral.com/1747-5341/
# https://ABBREVIATION.biomedcentral.com
# https://ABBREVIATION.biomedcentral.com/submission-guidelines
# ['http:', '', 'www.biomedcentral.com', '1747-5341', '']
# ['https:', '', 'ABBREVIATION.biomedcentral.com']
# ['https:', '', 'ABBREVIATION.biomedcentral.com', 'submission-guidelines ']
# Failure
# http://redc.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'redc.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://revintsociologia.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'revintsociologia.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://tp.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'tp.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://al-qantara.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'al-qantara.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://estudiosamericanos.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'estudiosamericanos.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://estudiosmedievales.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'estudiosmedievales.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://asclepio.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'asclepio.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://emerita.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'emerita.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://hispaniasacra.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'hispaniasacra.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://rdtp.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'rdtp.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://sefarad.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'sefarad.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://tp.revistas.csic.es/
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION
# http://ABBREVIATION.revistas.csic.es/index.php/ABBREVIATION/about/submissions#authorGuidelines
# ['http:', '', 'tp.revistas.csic.es', '']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION']
# ['http:', '', 'ABBREVIATION.revistas.csic.es', 'index.php', 'ABBREVIATION', 'about', 'submissions#authorGuidelines']
# Failure
# http://www.reference-global.com/loi/cogl
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'cogl']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/comm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'comm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.degruyter.de/journals/cllt/detailEn.cfm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.de', 'journals', 'cllt', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.degruyter.de/journals/dig/detailEn.cfm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.de', 'journals', 'dig', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/flih
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'flih']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/humr
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'humr']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/iprg
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'iprg']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.degruyter.de/journals/jall/detailEn.cfm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.de', 'journals', 'jall', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/jplr
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'jplr']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/tlir
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'tlir']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/ling
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'ling']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/mult
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'mult']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.versita.com/science/socialsciences/psicl/
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.versita.com', 'science', 'socialsciences', 'psicl', '']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/prbs
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'prbs']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.degruyter.de/journals/text/detailEn.cfm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.de', 'journals', 'text', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/zfsw
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'zfsw']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/cogl
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'cogl']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.degruyter.de/journals/cllt/detailEn.cfm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.de', 'journals', 'cllt', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.degruyter.de/journals/dig/detailEn.cfm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.de', 'journals', 'dig', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/flih
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'flih']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/humr
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'humr']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/iprg
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'iprg']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.degruyter.de/journals/jall/detailEn.cfm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.de', 'journals', 'jall', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/jlse
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'jlse']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/jplr
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'jplr']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/tlir
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'tlir']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/ling
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'ling']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/mult
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'mult']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.versita.com/science/socialsciences/psicl/
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.versita.com', 'science', 'socialsciences', 'psicl', '']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/prbs
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'prbs']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.degruyter.de/journals/text/detailEn.cfm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.de', 'journals', 'text', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.reference-global.com/loi/zfsw
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'zfsw']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.jos.nu
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.jos.nu']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader ']
# Failure
# http://www.eupjournals.com/journal/anh
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'anh']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/pah
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'pah']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/shr
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'shr']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/anh
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'anh']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/bjj
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'bjj']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/ccs
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'ccs']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/drs
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'drs']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/ircl
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'ircl']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/jbctv
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'jbctv']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/olr
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'olr']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/para
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'para']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/pah
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'pah']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/rom
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'rom']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/shr
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'shr']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://www.eupjournals.com/journal/swc
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'www.eupjournals.com', 'journal', 'swc']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://muse.jhu.edu/journals/translation_and_literature/
# https://www.euppublishing.com/page/ABBREVIATION
# https://www.euppublishing.com/page/ABBREVIATION/submissions
# ['http:', '', 'muse.jhu.edu', 'journals', 'translation_and_literature', '']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION']
# ['https:', '', 'www.euppublishing.com', 'page', 'ABBREVIATION', 'submissions ']
# Failure
# http://content.apa.org/journals/cdp
# https://www.apa.org/pubs/journals/ABBREVIATION/index.aspx
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'cdp']
# ['https:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', 'index.aspx']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://www.springerlink.com/openurl.asp?genre=journal&issn=1053-0797
# https://www.apa.org/pubs/journals/ABBREVIATION/index.aspx
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'www.springerlink.com', 'openurl.asp?genre=journal&issn=1053-0797']
# ['https:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', 'index.aspx']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/fsh
# https://www.apa.org/pubs/journals/ABBREVIATION/index.aspx
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'fsh']
# ['https:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', 'index.aspx']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/gdn
# https://www.apa.org/pubs/journals/ABBREVIATION/index.aspx
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'gdn']
# ['https:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', 'index.aspx']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://content.apa.org/journals/hop
# https://www.apa.org/pubs/journals/ABBREVIATION/index.aspx
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ['http:', '', 'content.apa.org', 'journals', 'hop']
# ['https:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', 'index.aspx']
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']
# Failure
# http://www.apa.org/pubs/journals/per/
# https://www.apa.org/pubs/journals/ABBREVIATION/index.aspx
# http://www.apa.org/pubs/journals/ABBREVIATION/?tab=4
# ...
# ['http:', '', 'www.degruyter.de', 'journals', 'iral', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.luciusverlag.com/zeitschriften/jahrbuecher/jahrbuecher_nationaloekonomie_statistik.htm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.luciusverlag.com', 'zeitschriften', 'jahrbuecher', 'jahrbuecher_nationaloekonomie_statistik.htm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.degruyter.com/view/j/jhsem
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.com', 'view', 'j', 'jhsem']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/libr
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'libr']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/lity
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'lity']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/prhz
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'prhz']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.degruyter.de/journals/restaur/detailEn.cfm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.de', 'journals', 'restaur', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.degruyter.com/view/j/rne
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.com', 'view', 'j', 'rne']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/semi
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'semi']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.bepress.com/snde/
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.bepress.com', 'snde', '']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/thli
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'thli']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.degruyter.com/view/j/angl
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.com', 'view', 'j', 'angl']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.degruyter.com/view/j/anti
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.com', 'view', 'j', 'anti']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.degruyter.com/view/j/arca
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.com', 'view', 'j', 'arca']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.degruyter.com/view/j/agph
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.com', 'view', 'j', 'agph']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.degruyter.com/view/j/apf
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.com', 'view', 'j', 'apf']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/bgsl
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'bgsl']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/byzs
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'byzs']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.akademie-verlag.de/olb/1.c.1120111.de
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.akademie-verlag.de', 'olb', '1.c.1120111.de']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/fabl
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'fabl']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/flin
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'flin']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.oldenbourg-wissenschaftsverlag.de/olb/de/1.c.335311.de
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.oldenbourg-wissenschaftsverlag.de', 'olb', 'de', '1.c.335311.de']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/iber
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'iber']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.degruyter.de/journals/igf/detailEn.cfm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.de', 'journals', 'igf', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.degruyter.de/journals/iasl/detailEn.cfm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.de', 'journals', 'iasl', 'detailEn.cfm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/islm
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'islm']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/kant
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'kant']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/lity
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'lity']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.degruyter.com/view/j/mgzs
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.degruyter.com', 'view', 'j', 'mgzs']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/nzst
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'nzst']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.akademie-verlag.de/olb/1.c.1120123.de
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.akademie-verlag.de', 'olb', '1.c.1120123.de']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/prhz
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'prhz']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/semi
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'semi']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/thli
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'thli']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.oldenbourg-wissenschaftsverlag.de/olb/de/1.c.335323.de
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.oldenbourg-wissenschaftsverlag.de', 'olb', 'de', '1.c.335323.de']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.akademie-verlag.de/olb/1.c.1120129.de
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.akademie-verlag.de', 'olb', '1.c.1120129.de']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/zach
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'zach']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/zava
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'zava']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/zatw
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'zatw']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/zntw
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'zntw']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/zfgl
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'zfgl']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.reference-global.com/loi/zrph
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.reference-global.com', 'loi', 'zrph']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure
# http://www.akademie-verlag.de/olb/1.c.1120132.de
# https://www.degruyter.com/view/j/ABBREVIATION
# https://www.degruyter.com/view/j/ABBREVIATION#callForPapersHeader
# ['http:', '', 'www.akademie-verlag.de', 'olb', '1.c.1120132.de']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION']
# ['https:', '', 'www.degruyter.com', 'view', 'j', 'ABBREVIATION#callForPapersHeader']
# Failure

# %%
wb.save('input2.xlsx')

# %%
x = 'per'
y = ['http:', '', 'www.apa.org', 'pubs', 'journals', 'ABBREVIATION', '?tab=4']

temp = [w.replace('ABBREVIATION', x) for w in y]
print(temp)
# Out:
# ['http:', '', 'www.apa.org', 'pubs', 'journals', 'per', '?tab=4']
